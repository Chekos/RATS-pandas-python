# %%
import pandas as pd

# %%
df = pd.read_stata('../data/raw/pandas_wkshp2.dta')

df.head().T
# Out:
#                                              0  \
# year                                      2000
# datanum                                      3
# serial                                     218
# hhwt                                       600
# statefip                            California
# countyfips                                 NaN
# gq            Households under 1970 definition
# pernum                                       1
# perwt                                      671
# sex                                       Male
# age                                         65
# marst                  Married, spouse present
# race                                     White
# raced                                    White
# bpl                         United Kingdom, ns
# bpld                        United Kingdom, ns
# citizen                          Not a citizen
# hcovany                                    NaN
# hcovpriv                                   NaN
# ...

# %%
df.groupby(['year', 'citizen', 'educd'])['perwt'].sum()
# Out:
# year  citizen                          educd
# 2000  N/A                              No schooling completed                             2443.0
#                                        Grade 5 or 6                                        622.0
#                                        Grade 7 or 8                                       3405.0
#                                        Grade 9                                             967.0
#                                        Grade 10                                           4877.0
#                                        Grade 11                                           4290.0
#                                        12th grade, no diploma                             4326.0
#                                        High school graduate or GED                       41086.0
#                                        Some college, but less than 1 year                11009.0
# ...

# %%
df['educd'].cat.categories
# Out:
# Index(['No schooling completed', 'Nursery school to grade 4',
#        'Nursery school, preschool', 'Kindergarten', 'Grade 1', 'Grade 2',
#        'Grade 3', 'Grade 4', 'Grade 5 or 6', 'Grade 5', 'Grade 6',
#        'Grade 7 or 8', 'Grade 7', 'Grade 8', 'Grade 9', 'Grade 10', 'Grade 11',
#        '12th grade, no diploma', 'High school graduate or GED',
#        'Regular high school diploma', 'GED or alternative credential',
#        'Some college, but less than 1 year',
#        '1 or more years of college credit, no degree',
#        'Associate's degree, type not specified', 'Bachelor's degree',
#        'Master's degree', 'Professional degree beyond a bachelor's degree',
#        'Doctoral degree'],
#       dtype='object')

# %%
df[df['educd'] < "High school graduate or GED"]
# Out:
#        year  datanum    serial    hhwt    statefip  countyfips  \
# 2      2000        3     784.0   600.0  California         NaN
# 5      2000        3    1681.0   600.0  California         NaN
# 16     2000        3    6401.0  1800.0  California         NaN
# 19     2000        3    8152.0  1800.0  California         NaN
# 20     2000        3    8195.0   600.0  California         NaN
# 24     2000        3   10079.0   600.0  California         NaN
# 25     2000        3   10175.0   600.0  California         NaN
# 30     2000        3   13488.0  1800.0  California         NaN
# 36     2000        3   15878.0   600.0  California         NaN
# 38     2000        3   17850.0   600.0  California         NaN
# 39     2000        3   17934.0   600.0  California         NaN
# 56     2000        3   28343.0   600.0  California         NaN
# 58     2000        3   29382.0   600.0  California         NaN
# 60     2000        3   29958.0   600.0  California         NaN
# ...

# %% [markdown]
# # make categories for the blog post that I worked on last time
# show other notebooks for datacleaning for later use if they're intersted
