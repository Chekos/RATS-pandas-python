# %%
import pandas as pd

# %%
df = pd.read_stata("../../data/raw/pandas_wkshp.dta")

df.head()
# Out:
#    year  datanum  serial   hhwt    statefip  countyfips  \
# 0  2000        3   218.0  600.0  California         NaN
# 1  2000        3   226.0  600.0  California         NaN
# 2  2000        3   784.0  600.0  California         NaN
# 3  2000        3  1033.0  600.0  California         NaN
# 4  2000        3  1115.0  600.0  California         NaN
#
#                                  gq  pernum  perwt     sex  \
# 0  Households under 1970 definition       1  671.0    Male
# 1  Households under 1970 definition       2  610.0  Female
# 2  Households under 1970 definition       2  618.0  Female
# 3  Households under 1970 definition       1  637.0    Male
# 4  Households under 1970 definition       1  579.0  Female
#
#             ...                       empstat              empstatd  \
# 0           ...            Not in labor force    Not in Labor Force
# 1           ...                      Employed  Has job, not working
# ...

# %%
df.shape
# Out:
# (48215, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48215 entries, 0 to 48214
# Data columns (total 37 columns):
# year          48215 non-null category
# datanum       48215 non-null int8
# serial        48215 non-null float64
# hhwt          48215 non-null float64
# statefip      48215 non-null category
# countyfips    44453 non-null float64
# gq            48215 non-null category
# pernum        48215 non-null int16
# perwt         48215 non-null float64
# sex           48215 non-null category
# age           48215 non-null category
# marst         48215 non-null category
# race          48215 non-null category
# raced         48215 non-null category
# bpl           48215 non-null category
# bpld          48215 non-null category
# citizen       48215 non-null category
# hcovany       35876 non-null category
# hcovpriv      35876 non-null category
# hinsemp       35876 non-null category
# hinspur       35876 non-null category
# hcovpub       35876 non-null category
# ...

# %%
df.describe()
# Out:
#             datanum         serial          hhwt    countyfips        pernum  \
# count  48215.000000   48215.000000  48215.000000  44453.000000  48215.000000
# mean       1.011781  131550.624038    100.656663     53.071356      1.619455
# std        0.153045   47366.501156     98.003737     29.018049      1.077433
# min        1.000000     218.000000      2.000000      0.000000      1.000000
# 25%        1.000000   94007.000000     59.000000     37.000000      1.000000
# 50%        1.000000  132436.000000     72.000000     59.000000      1.000000
# 75%        1.000000  171733.000000    108.000000     73.000000      2.000000
# max        3.000000  216032.000000   2002.000000    113.000000     19.000000
#
#               perwt           ind
# count  48215.000000  48215.000000
# mean     104.936596   3855.261869
# std      104.101244   3719.635336
# min        2.000000      0.000000
# 25%       60.000000      0.000000
# 50%       75.000000   3580.000000
# ...

# %%
df.head().T
# Out:
#                                              0  \
# year                                      2000
# datanum                                      3
# serial                                     218
# hhwt                                       600
# statefip                            California
# countyfips                                 NaN
# gq            Households under 1970 definition
# pernum                                       1
# perwt                                      671
# sex                                       Male
# age                                         65
# marst                  Married, spouse present
# race                                     White
# raced                                    White
# bpl                         United Kingdom, ns
# bpld                        United Kingdom, ns
# citizen                          Not a citizen
# hcovany                                    NaN
# hcovpriv                                   NaN
# ...

# %%
df.groupby(['year', 'vetstat', 'empstat'])['perwt'].sum().to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-8303483f584d> in <module>()
# ----> 1 df.groupby(['year', 'vetstat', 'empstat'])['perwt'].sum().to_frame().app
#
# ~\AppData\Local\Continuum\anaconda3\envs\pandas_wkshp2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'app'

# %%
vet_group = df[df['empstat'] != 'Not in labor force'].groupby(['year', 'vetstat', 'empstat']).agg({'perwt': 'sum'})
# Change: groupby state_office and divide by sum
vet_pcts = vet_group.groupby(level=[0,1]).apply(lambda x: x / float(x.sum()))

# %%
vet_pcts.style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_383846ee_ab14_11e8_bc36_0050b6701502" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >perwt</th>
#     </tr>    <tr>
#         <th class="index_name level0" >year</th>
#         <th class="index_name level1" >vetstat</th>
#         <th class="index_name level2" >empstat</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_383846ee_ab14_11e8_bc36_0050b6701502level0_row0" class="row_heading level0 row0" rowspan=4>2000</th>
#         <th id="T_383846ee_ab14_11e8_bc36_0050b6701502level1_row0" class="row_heading level1 row0" rowspan=2>Not a veteran</th>
#         <th id="T_383846ee_ab14_11e8_bc36_0050b6701502level2_row0" class="row_heading level2 row0" >Employed</th>
# ...

# %%
vet_group
# Out:
#                                   perwt
# year vetstat       empstat
# 2000 Not a veteran Employed     52414.0
#                    Unemployed    4631.0
#      Veteran       Employed     15862.0
#                    Unemployed     597.0
# 2001 Not a veteran Employed     45811.0
#                    Unemployed    2157.0
#      Veteran       Employed     14524.0
#                    Unemployed     531.0
# 2002 Not a veteran Employed     50933.0
#                    Unemployed    2024.0
#      Veteran       Employed     19183.0
#                    Unemployed     512.0
# 2003 Not a veteran Employed     53659.0
#                    Unemployed    5376.0
#      Veteran       Employed     20857.0
#                    Unemployed    2178.0
# 2004 Not a veteran Employed     57533.0
#                    Unemployed    3847.0
#      Veteran       Employed     18807.0
#                    Unemployed     379.0
# 2005 Not a veteran Employed     61649.0
#                    Unemployed    2909.0
# ...

# %%
vet_gg = df.groupby(['year', 'vetstat'])['perwt'].sum()
vet_gg_pctg = vet_gg.groupby(level=0).apply(lambda x: x / x.sum())

# %%
# %matplotlib inline
vet_gg_pctg.plot.bar()
