# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/raw/usa_00025.csv")

# %%
df.shape
# Out:
# (48215, 39)

# %%
df.head()
# Out:
#    YEAR  DATANUM  SERIAL  HHWT  STATEFIP  COUNTYFIPS  GQ  PERNUM  PERWT  SEX  \
# 0  2000        3     218   600         6         NaN   1       1    671    1
# 1  2000        3     226   600         6         NaN   1       2    610    2
# 2  2000        3     784   600         6         NaN   1       2    618    2
# 3  2000        3    1033   600         6         NaN   1       1    637    1
# 4  2000        3    1115   600         6         NaN   1       1    579    2
#
#      ...     OCC2010  IND  WKSWORK2  UHRSWORK  LOOKING  AVAILBLE  INCTOT  \
# 0    ...         150  607         0         0        1         0   24800
# 1    ...         410  707         2        30        1         3  103640
# 2    ...        9920    0         0         0        1         0   34000
# 3    ...        6005   27         6        50        0         0   37500
# 4    ...         410  707         6        16        1         3  145000
#
#    INCWAGE  VETSTAT  VETSTATD
# 0        0        1        11
# ...
